# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pickle as pkl
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, RidgeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import Normalizer
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, confusion_matrix

# %% [markdown]
# ## Loading Data

# %%
df=pd.read_excel("C:\machine learning\Liver_cirosis\HealthCareData.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\aniki\anaconda3\envs\kidney\lib\site-packages\pandas\compat\_optional.py:142, in import_optional_dependency(name, extra, errors, min_version)
#     141 try:
# --> 142     module = importlib.import_module(name)
#     143 except ImportError:
#
# File c:\Users\aniki\anaconda3\envs\kidney\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:973, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df=pd.read_excel("C:\machine learning\Liver_cirosis\HealthCareData.xlsx")
#
# File c:\Users\aniki\anaconda3\envs\kidney\lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File c:\Users\aniki\anaconda3\envs\kidney\lib\site-packages\pandas\io\excel\_base.py:1513, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1510 self.engine = engine
#    1511 self.storage_options = storage_options
# -> 1513 self._reader = self._engines[engine](self._io, storage_options=storage_options)
#
# File c:\Users\aniki\anaconda3\envs\kidney\lib\site-packages\pandas\io\excel\_openpyxl.py:548, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options)
#     533 @doc(storage_options=_shared_docs["storage_options"])
#     534 def __init__(
#     535     self,
#     536     filepath_or_buffer: FilePath | ReadBuffer[bytes],
#     537     storage_options: StorageOptions = None,
#     538 ) -> None:
#     539     """
#     540     Reader using openpyxl engine.
#     541
#    (...)
#     546     {storage_options}
#     547     """
# --> 548     import_optional_dependency("openpyxl")
#     549     super().__init__(filepath_or_buffer, storage_options=storage_options)
#
# File c:\Users\aniki\anaconda3\envs\kidney\lib\site-packages\pandas\compat\_optional.py:145, in import_optional_dependency(name, extra, errors, min_version)
#     143 except ImportError:
#     144     if errors == "raise":
# --> 145         raise ImportError(msg)
#     146     return None
#     148 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %% [markdown]
# Knowing the Data

# %%
df.head()
# Out:
#    S.NO  Age  Gender Place(location where the patient lives)  \
# 0     1   55    male                                   rural
# 1     2   55    male                                   rural
# 2     3   55    male                                   rural
# 3     4   55    male                                   rural
# 4     5   55  female                                   rural
#
#    Duration of alcohol consumption(years)  \
# 0                                      12
# 1                                      12
# 2                                      12
# 3                                      12
# 4                                      12
#
#    Quantity of alcohol consumption (quarters/day) Type of alcohol consumed  \
# 0                                               2           branded liquor
# 1                                               2           branded liquor
# 2                                               2           branded liquor
# 3                                               2           branded liquor
# 4                                               2           branded liquor
#
#   Hepatitis B infection Hepatitis C infection Diabetes Result  ...  \
# 0              negative              negative             YES  ...
# 1              negative              negative             YES  ...
# 2              negative              negative             YES  ...
# 3              negative              negative              NO  ...
# 4              negative              negative             YES  ...
#
#   Indirect     (mg/dl) Total Protein     (g/dl) Albumin   (g/dl)  \
# 0                  3.0                      6.0              3.0
# 1                  3.0                      6.0              3.0
# 2                  3.0                      6.0              3.0
# 3                  3.0                      6.0              3.0
# 4                  3.0                      6.0              3.0
#
#    Globulin  (g/dl) A/G Ratio AL.Phosphatase      (U/L)  SGOT/AST      (U/L)  \
# 0               4.0      0.75                     150.0                   56
# 1               4.0      0.75                     150.0                   56
# 2               4.0      0.75                     150.0                   56
# 3               4.0      0.75                     150.0                   56
# 4               4.0      0.75                     150.0                   56
#
#    SGPT/ALT (U/L)  USG Abdomen (diffuse liver or  not)  \
# 0              34                                  YES
# 1              34                                  YES
# 2              34                                  YES
# 3              34                                  YES
# 4              34                                  YES
#
#    Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (950, 42)

# %% [markdown]
# We can see that the outcome is highly unbalanced

# %%
df["Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)"].value_counts()
# Out:
# Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)
# YES    876
# no      20
# Name: count, dtype: int64

# %% [markdown]
# We synthetically generate 300 rows where outcome is no with the help of RANDOM module

# %%
"""import pandas as pd
import random

# Select rows where Outcome is "NO"
df_no_outcome = df[df["Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)"] == "no"]

# Check if df_no_outcome is empty and handle it accordingly
if df_no_outcome.empty:
    print("No rows found with 'NO' outcome. Cannot generate synthetic data.")
else:
    # Generate synthetic rows based on existing "NO" outcome rows
    synthetic_rows = []
    num_synthetic_samples = 300  # Number of synthetic samples to generate

    for _ in range(num_synthetic_samples):
        # Randomly select a row from df_no_outcome
        selected_row = df_no_outcome.sample(n=1).iloc[0]

        # Create a new row with random values based on the selected row
        synthetic_row = selected_row.copy()
        for column in df_no_outcome.columns:
            if df_no_outcome[column].dtype in ["int64", "float64"]:
                # Add noise within a 10% range of the selected row's value
                noise_factor = 0.1 * selected_row[column]
                synthetic_row[column] = random.uniform(selected_row[column] - noise_factor, selected_row[column] + noise_factor)
            elif df_no_outcome[column].dtype == "object":
                synthetic_row[column] = random.choice(df_no_outcome[column].unique())

        synthetic_rows.append(synthetic_row)

    # Convert synthetic rows to a DataFrame and append to the original DataFrame
    synthetic_df = pd.DataFrame(synthetic_rows, columns=df_no_outcome.columns)
    df = pd.concat([df, synthetic_df], ignore_index=True)"""
# Out:
# 'import pandas as pd\nimport random\n\n# Select rows where Outcome is "NO"\ndf_no_outcome = df[df["Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)"] == "no"]\n\n# Check if df_no_outcome is empty and handle it accordingly\nif df_no_outcome.empty:\n    print("No rows found with \'NO\' outcome. Cannot generate synthetic data.")\nelse:\n    # Generate synthetic rows based on existing "NO" outcome rows\n    synthetic_rows = []\n    num_synthetic_samples = 300  # Number of synthetic samples to generate\n\n    for _ in range(num_synthetic_samples):\n        # Randomly select a row from df_no_outcome\n        selected_row = df_no_outcome.sample(n=1).iloc[0]\n\n        # Create a new row with random values based on the selected row\n        synthetic_row = selected_row.copy()\n        for column in df_no_outcome.columns:\n            if df_no_outcome[column].dtype in ["int64", "float64"]:\n                # Add noise within a 10% range of the selected row\'s value\n                noise_factor = 0.1 * selected_row[column]\n                synthetic_row[column] = random.uniform(selected_row[column] - noise_factor, selected_row[column] + noise_factor)\n            elif df_no_outcome[column].dtype == "object":\n                synthetic_row[column] = random.choice(df_no_outcome[column].unique())\n\n        synthetic_rows.append(synthetic_row)\n\n    # Convert synthetic rows to a DataFrame and append to the original DataFrame\n    synthetic_df = pd.DataFrame(synthetic_rows, columns=df_no_outcome.columns)\n    df = pd.concat([df, synthetic_df], ignore_index=True)'

# %%
df.shape
# Out:
# (950, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 42 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   S.NO                                                                     950 non-null    int64
#  1   Age                                                                      950 non-null    int64
#  2   Gender                                                                   950 non-null    object
#  3   Place(location where the patient lives)                                  816 non-null    object
#  4   Duration of alcohol consumption(years)                                   950 non-null    int64
#  5   Quantity of alcohol consumption (quarters/day)                           950 non-null    int64
#  6   Type of alcohol consumed                                                 950 non-null    object
#  7   Hepatitis B infection                                                    950 non-null    object
#  8   Hepatitis C infection                                                    950 non-null    object
#  9   Diabetes Result                                                          950 non-null    object
#  10  Blood pressure (mmhg)                                                    950 non-null    object
#  11  Obesity                                                                  950 non-null    object
#  12  Family history of cirrhosis/ hereditary                                  950 non-null    object
#  13  TCH                                                                      591 non-null    float64
#  14  TG                                                                       591 non-null    object
#  15  LDL                                                                      591 non-null    object
#  16  HDL                                                                      582 non-null    float64
#  17  Hemoglobin  (g/dl)                                                       950 non-null    float64
#  18  PCV  (%)                                                                 920 non-null    float64
#  19  RBC  (million cells/microliter)                                          398 non-null    float64
#  20  MCV   (femtoliters/cell)                                                 941 non-null    float64
#  21  MCH  (picograms/cell)                                                    292 non-null    float64
#  22  MCHC  (grams/deciliter)                                                  278 non-null    float64
#  23  Total Count                                                              940 non-null    float64
#  24  Polymorphs  (%)                                                          950 non-null    float64
#  25  Lymphocytes  (%)                                                         950 non-null    float64
#  26  Monocytes   (%)                                                          941 non-null    float64
#  27  Eosinophils   (%)                                                        942 non-null    float64
#  28  Basophils  (%)                                                           901 non-null    float64
#  29  Platelet Count  (lakhs/mm)                                               950 non-null    float64
#  30  Total Bilirubin    (mg/dl)                                               950 non-null    object
#  31  Direct    (mg/dl)                                                        950 non-null    float64
#  32  Indirect     (mg/dl)                                                     895 non-null    float64
#  33  Total Protein     (g/dl)                                                 889 non-null    float64
#  34  Albumin   (g/dl)                                                         941 non-null    float64
#  35  Globulin  (g/dl)                                                         921 non-null    float64
#  36  A/G Ratio                                                                591 non-null    object
#  37  AL.Phosphatase      (U/L)                                                940 non-null    float64
#  38  SGOT/AST      (U/L)                                                      950 non-null    int64
#  39  SGPT/ALT (U/L)                                                           950 non-null    int64
#  40  USG Abdomen (diffuse liver or  not)                                      950 non-null    object
#  41  Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)  896 non-null    object
# dtypes: float64(21), int64(6), object(15)
# memory usage: 311.8+ KB

# %% [markdown]
# Total null values

# %%
df.isnull().sum()
# Out:
# S.NO                                                                         0
# Age                                                                          0
# Gender                                                                       0
# Place(location where the patient lives)                                    134
# Duration of alcohol consumption(years)                                       0
# Quantity of alcohol consumption (quarters/day)                               0
# Type of alcohol consumed                                                     0
# Hepatitis B infection                                                        0
# Hepatitis C infection                                                        0
# Diabetes Result                                                              0
# Blood pressure (mmhg)                                                        0
# Obesity                                                                      0
# Family history of cirrhosis/ hereditary                                      0
# TCH                                                                        359
# TG                                                                         359
# LDL                                                                        359
# HDL                                                                        368
# Hemoglobin  (g/dl)                                                           0
# PCV  (%)                                                                    30
# RBC  (million cells/microliter)                                            552
# MCV   (femtoliters/cell)                                                     9
# MCH  (picograms/cell)                                                      658
# MCHC  (grams/deciliter)                                                    672
# Total Count                                                                 10
# Polymorphs  (%)                                                              0
# Lymphocytes  (%)                                                             0
# Monocytes   (%)                                                              9
# Eosinophils   (%)                                                            8
# Basophils  (%)                                                              49
# Platelet Count  (lakhs/mm)                                                   0
# Total Bilirubin    (mg/dl)                                                   0
# Direct    (mg/dl)                                                            0
# Indirect     (mg/dl)                                                        55
# Total Protein     (g/dl)                                                    61
# Albumin   (g/dl)                                                             9
# Globulin  (g/dl)                                                            29
# A/G Ratio                                                                  359
# AL.Phosphatase      (U/L)                                                   10
# SGOT/AST      (U/L)                                                          0
# SGPT/ALT (U/L)                                                               0
# USG Abdomen (diffuse liver or  not)                                          0
# Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)     54
# dtype: int64

# %% [markdown]
# All duplicate rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# All the object columns in the dataset

# %%
object_cols = df.select_dtypes(include='object').columns.tolist()
for col in object_cols:
  print(col)
# Out:
# Gender
# Place(location where the patient lives)
# Type of alcohol consumed
# Hepatitis B infection
# Hepatitis C infection
# Diabetes Result
# Blood pressure (mmhg)
# Obesity
# Family history of cirrhosis/ hereditary
# TG
# LDL
# Total Bilirubin    (mg/dl)
# A/G Ratio
# USG Abdomen (diffuse liver or  not)
# Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)

# %% [markdown]
# We can see TG LDL and Bilirubin are object type but they have numeric values

# %%
print(df["TG"].head(3))
print(df["LDL"].head(3))
print(df["Total Bilirubin    (mg/dl)"].head(3))
# Out:
# 0    115
# 1    115
# 2    115
# Name: TG, dtype: object
# 0    120
# 1    120
# 2    120
# Name: LDL, dtype: object
# 0    7
# 1    7
# 2    7
# Name: Total Bilirubin    (mg/dl), dtype: object

# %% [markdown]
# By using value_counts() we can notice that:
#
# *   TG contains a row - 130LDL
# *   LD contains a row - HDL
# *   Bilirubin contains a row - o.4

# %%
print(df["TG"].value_counts())
print(df["LDL"].value_counts())
print(df["Total Bilirubin    (mg/dl)"].value_counts())
# Out:
# TG
# 160       65
# 156       42
# 120       37
# 184       32
# 180       30
# 190       28
# 170       27
# 166       19
# 186       18
# 172       18
# 174       17
# 136       14
# 168       13
# 146       13
# 150       11
# 140       11
# 118       11
# 130       10
# 197       10
# 151       10
# 188       10
# 178        9
# 195        9
# 115        9
# 173        9
# 177        9
# 100        9
# 86         9
# 162        9
# 171        8
# 176        8
# 206        8
# 192        8
# 200        8
# 189        8
# 106        8
# 164        8
# 144        7
# 139        1
# 130LDL     1
# Name: count, dtype: int64
# LDL
# 120    82
# 110    58
# 108    56
# 96     50
# 105    40
# 104    33
# 79     32
# 116    18
# 90     18
# 85     17
# 98     17
# 109    14
# 129    13
# 80     11
# 122    10
# 136    10
# 115    10
# 88     10
# 94     10
# 65      9
# 49      9
# 200     9
# 180     9
# 100     9
# 99      9
# 91      9
# 86      8
# 106     8
# HDL     1
# 220     1
# 111     1
# Name: count, dtype: int64
# Total Bilirubin    (mg/dl)
# 7       77
# 4.8     48
# 4.2     40
# 6       40
# 6.8     39
# 8.4     39
# 5.6     38
# 10.9    30
# 5       30
# 4       30
# 5.2     29
# 2       29
# 6.6     29
# 5.1     29
# 9       28
# 7.6     28
# 5.8     28
# 3       20
# 7.8     19
# 4.6     19
# 6.4     19
# 7.2     19
# 6.9     18
# 6.2     12
# 10      11
# 8.2     10
# 11      10
# 4.4     10
# 1.4     10
# 8       10
# 7.1     10
# 5.7     10
# 5.4     10
# 9.2     10
# 8.6     10
# 4.7     10
# 8.7      9
# 4.3      9
# 1.2      9
# 7.5      9
# 4.5      9
# 8.3      9
# 8.9      9
# 3.2      9
# 0.5      6
# 0.3      5
# 0.7      4
# 0.6      3
# o.4      2
# Name: count, dtype: int64

# %% [markdown]
# Dropping those rows

# %%
df = df[df['TG'] != '130LDL']
df = df[df['LDL'] != 'HDL']
df = df[df['Total Bilirubin    (mg/dl)'] != 'o.4']

# %% [markdown]
# Converting into float

# %%
df["TG"] = df["TG"].astype(float)
df["LDL"] = df["LDL"].astype(float)
df["Total Bilirubin    (mg/dl)"] = df["Total Bilirubin    (mg/dl)"].astype(float)

# %% [markdown]
# ## Cleansing Numerical Columns

# %% [markdown]
# Checking for abnormal distribution in Quantity of alcohol

# %%
df["Quantity of alcohol consumption (quarters/day)"].value_counts()
# Out:
# Quantity of alcohol consumption (quarters/day)
# 2      520
# 3      198
# 1      158
# 4       54
# 180     16
# 5        1
# Name: count, dtype: int64

# %% [markdown]
# Removing the abnormalities

# %%
df["Quantity of alcohol consumption (quarters/day)"] = df["Quantity of alcohol consumption (quarters/day)"].replace(180, 5)

# %%
df["Quantity of alcohol consumption (quarters/day)"].value_counts()
# Out:
# Quantity of alcohol consumption (quarters/day)
# 2    520
# 3    198
# 1    158
# 4     54
# 5     17
# Name: count, dtype: int64

# %% [markdown]
# Checking abnormalities in platelets

# %%
df["Platelet Count  (lakhs/mm)"].value_counts()
# Out:
# Platelet Count  (lakhs/mm)
# 1.200        100
# 1.500         84
# 1.800         68
# 1.000         51
# 1.100         49
# 1.700         46
# 1.400         41
# 1.600         37
# 1.900         29
# 2.300         22
# 2.000         20
# 1.670         20
# 1.300         20
# 1.380         20
# 0.980         19
# 1.550         19
# 1.420         18
# 2.400         11
# 1.350         10
# 1.320         10
# 1.170         10
# 1.280         10
# 1.020         10
# 2.800         10
# 1.090         10
# 1.560         10
# 1.760         10
# 0.520         10
# 0.650         10
# 1.580         10
# 2.200         10
# 0.910         10
# 0.780         10
# 1.160         10
# 1.036         10
# 1.210         10
# 1.450         10
# 0.940          9
# 1.220          9
# 1.830          9
# 1.920          9
# 1.520          9
# 1.340          9
# 1.230          9
# 0.900          5
# 90000.000      5
# 3.000          3
# 1.750          2
# 2.500          2
# 3.200          2
# 0.550          1
# Name: count, dtype: int64

# %% [markdown]
# Removing the abnormalities

# %%
df = df[df["Platelet Count  (lakhs/mm)"] != 90000.000]

# %% [markdown]
# Filling all numerical columns with their mean

# %%
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
for col in numerical_columns:
  df[col].fillna(df[col].mean(), inplace=True)

df.isnull().sum()
# Out:
# S.NO                                                                         0
# Age                                                                          0
# Gender                                                                       0
# Place(location where the patient lives)                                    133
# Duration of alcohol consumption(years)                                       0
# Quantity of alcohol consumption (quarters/day)                               0
# Type of alcohol consumed                                                     0
# Hepatitis B infection                                                        0
# Hepatitis C infection                                                        0
# Diabetes Result                                                              0
# Blood pressure (mmhg)                                                        0
# Obesity                                                                      0
# Family history of cirrhosis/ hereditary                                      0
# TCH                                                                          0
# TG                                                                           0
# LDL                                                                          0
# HDL                                                                          0
# Hemoglobin  (g/dl)                                                           0
# PCV  (%)                                                                     0
# RBC  (million cells/microliter)                                              0
# MCV   (femtoliters/cell)                                                     0
# MCH  (picograms/cell)                                                        0
# MCHC  (grams/deciliter)                                                      0
# Total Count                                                                  0
# Polymorphs  (%)                                                              0
# Lymphocytes  (%)                                                             0
# Monocytes   (%)                                                              0
# Eosinophils   (%)                                                            0
# Basophils  (%)                                                               0
# Platelet Count  (lakhs/mm)                                                   0
# Total Bilirubin    (mg/dl)                                                   0
# Direct    (mg/dl)                                                            0
# Indirect     (mg/dl)                                                         0
# Total Protein     (g/dl)                                                     0
# Albumin   (g/dl)                                                             0
# Globulin  (g/dl)                                                             0
# A/G Ratio                                                                  354
# AL.Phosphatase      (U/L)                                                    0
# SGOT/AST      (U/L)                                                          0
# SGPT/ALT (U/L)                                                               0
# USG Abdomen (diffuse liver or  not)                                          0
# Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)     54
# dtype: int64

# %%
df["TG"] = df["TG"].astype(int)
df["LDL"] = df["LDL"].astype(int)

# %% [markdown]
# Viewing A/G ratio

# %%
df["A/G Ratio"].value_counts()
# Out:
# A/G Ratio
# 0.75                   86
# 01:01:00               59
# 01:03:00               32
# 01:02:00               28
# 1900-01-01 00:00:00    24
# 02:01:00               21
# 1.214                  20
# 0.6                    20
# 1.5:1                  19
# 0.5                    19
# 0.77                   18
# 0.87                   18
# 03:01:00               16
# 0.6:1                  13
# 02:03:00               12
# 0.44                   10
# 0.575                  10
# 0.42                   10
# 0.8                    10
# 1.18                   10
# 0.84                   10
# 1.66                   10
# 2.2                     9
# 0.72                    9
# 0.86                    9
# 0.48                    9
# 0.31                    9
# 0.5.                    9
# 0.78                    9
# 2.45                    9
# 1.8                     6
# 1.68                    6
# 00:01:02.200000         6
# 12:00:00                4
# 00:01:00.875000         3
# 00:01:01.500000         3
# 00:01:03.500000         3
# 1900-01-03 00:00:00     3
# 1900-01-02 00:00:00     2
# 1900-01-01 06:24:00     1
# 00:01:03.100000         1
# 0.25                    1
# 1900-01-01 04:24:00     1
# 1900-01-01 05:24:00     1
# Name: count, dtype: int64

# %% [markdown]
# Checking Albumin abnormalities

# %%
df["Albumin   (g/dl)"].value_counts()
# Out:
# Albumin   (g/dl)
# 2.000000     148
# 3.000000     136
# 2.500000      69
# 3.200000      57
# 1.200000      51
# 2.100000      48
# 1.800000      38
# 2.800000      37
# 1.600000      30
# 2.700000      29
# 4.000000      28
# 2.900000      27
# 1.500000      21
# 2.300000      20
# 2.200000      19
# 3.100000      19
# 4.200000      12
# 1.000000      10
# 7.700000      10
# 1.900000      10
# 0.900000      10
# 1.400000      10
# 5.000000      10
# 3.400000      10
# 1.100000      10
# 22.000000      9
# 2.797106       9
# 2.600000       9
# 3.600000       9
# 4.600000       9
# 5.400000       9
# 8.100000       8
# 2.400000       5
# 4.500000       2
# 3.800000       2
# 5.200000       2
# Name: count, dtype: int64

# %% [markdown]
# Removing them

# %% [markdown]
# Checking Globulin and removing abnormalities

# %%
df=df[df["Albumin   (g/dl)"]!=22.0]

# %%
df["Globulin  (g/dl)"].value_counts()
# Out:
# Globulin  (g/dl)
# 4.000000     127
# 2.000000     118
# 3.000000      88
# 2.800000      65
# 2.500000      51
# 3.100000      47
# 3.500000      41
# 4.300000      38
# 1.000000      30
# 3.245455      29
# 3.800000      29
# 3.600000      27
# 4.100000      20
# 6.000000      19
# 3.300000      19
# 4.800000      19
# 2.200000      18
# 2.600000      18
# 4.200000      10
# 3.200000      10
# 4.500000      10
# 4.600000      10
# 4.900000      10
# 1.600000      10
# 4.400000      10
# 5.100000      10
# 2.700000      10
# 1.800000      10
# 2.300000       9
# 3.700000       9
# 3.900000       9
# 3.400000       2
# 30.000000      1
# Name: count, dtype: int64

# %%
df=df[df["Globulin  (g/dl)"]!=30.0]

# %% [markdown]
# Making it in the correct format

# %%
df["A/G Ratio"] = round(df["Albumin   (g/dl)"]/df["Globulin  (g/dl)"],2)

# %%
df["A/G Ratio"].value_counts()
# Out:
# A/G Ratio
# 1.00    99
# 0.75    87
# 0.67    49
# 0.43    30
# 0.50    30
# 0.61    29
# 0.86    24
# 1.14    20
# 3.00    20
# 1.50    20
# 0.32    20
# 0.89    19
# 0.49    19
# 0.87    19
# 0.81    19
# 2.00    19
# 0.54    18
# 0.78    18
# 0.90    18
# 0.46    11
# 1.20    11
# 0.37    11
# 0.42    10
# 1.10    10
# 0.44    10
# 1.19    10
# 0.64    10
# 0.60    10
# 1.68    10
# 0.29    10
# 0.39    10
# 0.36    10
# 0.40    10
# 0.84    10
# 0.25    10
# 1.67    10
# 1.21    10
# 0.38    10
# 0.57    10
# 2.20    10
# 0.94    10
# 0.41    10
# 0.79     9
# 1.82     9
# 2.45     9
# 0.33     9
# 2.30     9
# 0.77     9
# 0.69     9
# 1.23     9
# 0.93     9
# 0.88     9
# 1.07     9
# 0.72     9
# 2.50     8
# 1.80     2
# 1.27     2
# 1.53     2
# Name: count, dtype: int64

# %%
df["A/G Ratio"]=df["A/G Ratio"].astype(float)

# %%
df["A/G Ratio"].fillna(df["A/G Ratio"].mean(), inplace=True)

# %% [markdown]
# Viewing all null values left in the dataset

# %%
null_columns = df.isnull().sum()
null_columns = null_columns[null_columns > 0]
for column, count in null_columns.items():
  print(f"{column}: {count}")
# Out:
# Place(location where the patient lives): 133
# Predicted Value(Out Come-Patient suffering from liver  cirrosis or not): 54

# %% [markdown]
# ## Viewing the spread of data in Categorical columns

# %%
for i in df.columns:
  if df[i].dtype == 'object' and i!="Blood pressure (mmhg)":
    print(df[i].value_counts())
    print("-"*50)
# Out:
# Gender
# male           723
# female         194
# female          10
# transgender      5
# Name: count, dtype: int64
# --------------------------------------------------
# Place(location where the patient lives)
# rural    443
# urban    355
#  ocun      1
# Name: count, dtype: int64
# --------------------------------------------------
# Type of alcohol consumed
# country liquor     468
# both               282
# branded liquor     181
#  branded liquor      1
# Name: count, dtype: int64
# --------------------------------------------------
# Hepatitis B infection
# negative    779
# Positive    152
# positive      1
# Name: count, dtype: int64
# --------------------------------------------------
# Hepatitis C infection
# negative    796
# Positive    134
# positive      2
# Name: count, dtype: int64
# --------------------------------------------------
# Diabetes Result
# YES    633
# NO     299
# Name: count, dtype: int64
# --------------------------------------------------
# Obesity
# yes    536
# no     396
# Name: count, dtype: int64
# --------------------------------------------------
# Family history of cirrhosis/ hereditary
# no         854
# yes         66
# husband     12
# Name: count, dtype: int64
# --------------------------------------------------
# USG Abdomen (diffuse liver or  not)
# YES    895
# no      37
# Name: count, dtype: int64
# --------------------------------------------------
# Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)
# YES    860
# no      18
# Name: count, dtype: int64
# --------------------------------------------------

# %% [markdown]
# Cleaning the Place column

# %%
df = df[df['Place(location where the patient lives)'] != ' ocun']

# %% [markdown]
# Cleaning the Gender column

# %%
df["Gender"].replace("female ","female",inplace=True)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# male           722
# female         204
# transgender      5
# Name: count, dtype: int64

# %% [markdown]
# Cleaning alcohol conumption

# %%
df["Type of alcohol consumed"].replace(" branded liquor","branded liquor",inplace=True)

# %%
df["Type of alcohol consumed"].value_counts()
# Out:
# Type of alcohol consumed
# country liquor    468
# both              281
# branded liquor    182
# Name: count, dtype: int64

# %% [markdown]
# Cleaning hepatitis column

# %%
df["Hepatitis B infection"].replace("Positive","positive",inplace=True)
df["Hepatitis C infection"].replace("Positive","positive",inplace=True)

# %%
df["Hepatitis B infection"].value_counts()
# Out:
# Hepatitis B infection
# negative    778
# positive    153
# Name: count, dtype: int64

# %%
df["Hepatitis C infection"].value_counts()
# Out:
# Hepatitis C infection
# negative    795
# positive    136
# Name: count, dtype: int64

# %% [markdown]
# Cleaning family history column

# %%
df["Family history of cirrhosis/ hereditary"].replace("husband","yes",inplace=True)
df["Family history of cirrhosis/ hereditary"].value_counts()
# Out:
# Family history of cirrhosis/ hereditary
# no     853
# yes     78
# Name: count, dtype: int64

# %% [markdown]
# Converting rest of columns to proper format

# %%
df["Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)"].replace("YES","yes",inplace=True)
df["Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)"].value_counts()
# Out:
# Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)
# yes    859
# no      18
# Name: count, dtype: int64

# %% [markdown]
# # Checking data spread in categorical columns after cleaning

# %%
for i in df.columns:
  if df[i].dtype == 'object' and i!="Blood pressure (mmhg)":
    print(df[i].value_counts())
    print("-"*50)
# Out:
# Gender
# male           722
# female         204
# transgender      5
# Name: count, dtype: int64
# --------------------------------------------------
# Place(location where the patient lives)
# rural    443
# urban    355
# Name: count, dtype: int64
# --------------------------------------------------
# Type of alcohol consumed
# country liquor    468
# both              281
# branded liquor    182
# Name: count, dtype: int64
# --------------------------------------------------
# Hepatitis B infection
# negative    778
# positive    153
# Name: count, dtype: int64
# --------------------------------------------------
# Hepatitis C infection
# negative    795
# positive    136
# Name: count, dtype: int64
# --------------------------------------------------
# Diabetes Result
# YES    633
# NO     298
# Name: count, dtype: int64
# --------------------------------------------------
# Obesity
# yes    536
# no     395
# Name: count, dtype: int64
# --------------------------------------------------
# Family history of cirrhosis/ hereditary
# no     853
# yes     78
# Name: count, dtype: int64
# --------------------------------------------------
# USG Abdomen (diffuse liver or  not)
# YES    895
# no      36
# Name: count, dtype: int64
# --------------------------------------------------
# Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)
# yes    859
# no      18
# Name: count, dtype: int64
# --------------------------------------------------

# %% [markdown]
# Dropping unnecessary columns

# %%
df.drop(columns=["Place(location where the patient lives)","S.NO"],inplace=True)

# %% [markdown]
# Cleaning outcome

# %%
df.rename(columns={"Predicted Value(Out Come-Patient suffering from liver  cirrosis or not)": "Outcome"}, inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Duration of alcohol consumption(years)',
#        'Quantity of alcohol consumption (quarters/day)',
#        'Type of alcohol consumed', 'Hepatitis B infection',
#        'Hepatitis C infection', 'Diabetes Result', 'Blood pressure (mmhg)',
#        'Obesity', 'Family history of cirrhosis/ hereditary', 'TCH', 'TG',
#        'LDL', 'HDL', 'Hemoglobin  (g/dl)', 'PCV  (%)',
#        'RBC  (million cells/microliter)', 'MCV   (femtoliters/cell)',
#        'MCH  (picograms/cell)', 'MCHC  (grams/deciliter)', 'Total Count',
#        'Polymorphs  (%) ', 'Lymphocytes  (%)', 'Monocytes   (%)',
#        'Eosinophils   (%)', 'Basophils  (%)', 'Platelet Count  (lakhs/mm)',
#        'Total Bilirubin    (mg/dl)', 'Direct    (mg/dl)',
#        'Indirect     (mg/dl)', 'Total Protein     (g/dl)', 'Albumin   (g/dl)',
#        'Globulin  (g/dl)', 'A/G Ratio', 'AL.Phosphatase      (U/L)',
#        'SGOT/AST      (U/L)', 'SGPT/ALT (U/L)',
#        'USG Abdomen (diffuse liver or  not)', 'Outcome'],
#       dtype='object')

# %% [markdown]
# We can see that there are more yes than no

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# yes    859
# no      18
# Name: count, dtype: int64

# %%
df["Outcome"].isnull().sum()
# Out:
# 54

# %% [markdown]
# Filling all null values of the column with yes

# %%
df["Outcome"].fillna("yes", inplace=True)

# %% [markdown]
# ## **THE DATA HAS BEEN CLEANED**

# %%
df.isnull()
# Out:
#        Age  Gender  Duration of alcohol consumption(years)  \
# 0    False   False                                   False
# 1    False   False                                   False
# 2    False   False                                   False
# 3    False   False                                   False
# 4    False   False                                   False
# ..     ...     ...                                     ...
# 945  False   False                                   False
# 946  False   False                                   False
# 947  False   False                                   False
# 948  False   False                                   False
# 949  False   False                                   False
#
#      Quantity of alcohol consumption (quarters/day)  Type of alcohol consumed  \
# 0                                             False                     False
# 1                                             False                     False
# 2                                             False                     False
# 3                                             False                     False
# 4                                             False                     False
# ..                                              ...                       ...
# 945                                           False                     False
# 946                                           False                     False
# 947                                           False                     False
# 948                                           False                     False
# 949                                           False                     False
#
#      Hepatitis B infection  Hepatitis C infection  Diabetes Result  \
# 0                    False                  False            False
# 1                    False                  False            False
# 2                    False                  False            False
# 3                    False                  False            False
# 4                    False                  False            False
# ..                     ...                    ...              ...
# 945                  False                  False            False
# 946                  False                  False            False
# 947                  False                  False            False
# 948                  False                  False            False
# 949                  False                  False            False
#
#      Blood pressure (mmhg)  Obesity  ...  Indirect     (mg/dl)  \
# 0                    False    False  ...                 False
# 1                    False    False  ...                 False
# 2                    False    False  ...                 False
# 3                    False    False  ...                 False
# 4                    False    False  ...                 False
# ..                     ...      ...  ...                   ...
# 945                  False    False  ...                 False
# 946                  False    False  ...                 False
# 947                  False    False  ...                 False
# 948                  False    False  ...                 False
# 949                  False    False  ...                 False
#
#      Total Protein     (g/dl)  Albumin   (g/dl)  Globulin  (g/dl)  A/G Ratio  \
# 0                       False             False             False      False
# 1                       False             False             False      False
# 2                       False             False             False      False
# 3                       False             False             False      False
# 4                       False             False             False      False
# ..                        ...               ...               ...        ...
# 945                     False             False             False      False
# 946                     False             False             False      False
# 947                     False             False             False      False
# 948                     False             False             False      False
# 949                     False             False             False      False
#
#      AL.Phosphatase      (U/L)  SGOT/AST      (U/L)  SGPT/ALT (U/L)  \
# 0                        False                False           False
# 1                        False                False           False
# 2                        False                False           False
# 3                        False                False           False
# 4                        False                False           False
# ..                         ...                  ...             ...
# 945                      False                False           False
# 946                      False                False           False
# 947                      False                False           False
# 948                      False                False           False
# 949                      False                False           False
#
#      USG Abdomen (diffuse liver or  not)  Outcome
# 0                                  False    False
# 1                                  False    False
# 2                                  False    False
# 3                                  False    False
# 4                                  False    False
# ..                                   ...      ...
# 945                                False    False
# 946                                False    False
# 947                                False    False
# 948                                False    False
# 949                                False    False
#
# [931 rows x 40 columns]

# %% [markdown]
# ## Viewing all outliers and cleaning them

# %%
c=0
plt.figure(figsize=(20,15))
for i in df.columns:
  if(type(df[i][0])!=str):
    plt.subplot(7,5,c+1)
    # Attempt to convert the column to numeric, handling errors by coercing them to NaN
    sns.boxplot(df[i].apply(pd.to_numeric, errors='coerce'))
    plt.title(i)
    c=c+1
plt.show()

# %% [markdown]
# Removing using IQR

# %%
def remove_outliers(df, columns):
  for col in columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df[col] = np.where(df[col] < lower_bound, lower_bound,np.where(df[col] > upper_bound, upper_bound, df[col]))

numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
remove_outliers(df, numerical_columns)

# %%
c=0
plt.figure(figsize=(20,15))
for i in df.columns:
  if(type(df[i][0])!=str):
    plt.subplot(7,5,c+1)
    # Attempt to convert the column to numeric, handling errors by coercing them to NaN
    sns.boxplot(df[i].apply(pd.to_numeric, errors='coerce'))
    plt.title(i)
    c=c+1
plt.show()

# %% [markdown]
# ## *UNI-VARIATE ANALYSIS*

# %% [markdown]
# Representing all the important numerical columns in distplot

# %%
l=['Age','Duration of alcohol consumption(years)','Total Bilirubin    (mg/dl)','Hemoglobin  (g/dl)','Albumin   (g/dl)']

plt.figure(figsize=(20, 15))

for i, col in enumerate(l):
    plt.subplot(3, 2, i + 1)
    sns.distplot(df[col])
    plt.title(col)

plt.show()
# Out:
# C:\Users\aniki\AppData\Local\Temp\ipykernel_38032\23103084.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# C:\Users\aniki\AppData\Local\Temp\ipykernel_38032\23103084.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# C:\Users\aniki\AppData\Local\Temp\ipykernel_38032\23103084.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# C:\Users\aniki\AppData\Local\Temp\ipykernel_38032\23103084.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])
# C:\Users\aniki\AppData\Local\Temp\ipykernel_38032\23103084.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[col])

# %% [markdown]
# Inferences from Density Plots
#
#  **Age Distribution**:
#    - The majority of patients fall within the 40-60 age range.
#    - There is a noticeable peak around the age of 50, indicating a higher frequency of patients in their early 50s.
#
# 2. **Duration of Alcohol Consumption**:
#    - The duration of alcohol consumption varies widely among patients.
#    - A significant proportion of patients have been consuming alcohol for around 15-25 years, with a peak at approximately 20 years.
#
# 3. **Total Bilirubin**:
#    - The total bilirubin levels show a wide distribution, with a peak around 6 mg/dl.
#    - There are some patients with very high bilirubin levels, indicating possible liver dysfunction.
#
# 4. **Hemoglobin Levels**:
#    - Hemoglobin levels are generally distributed around a mean of approximately 10 g/dl.
#    - The distribution shows a peak around 10-12 g/dl, suggesting that most patients have moderate to normal hemoglobin levels.

# %% [markdown]
# Representing all the important catogorical columns in pie chart

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Type of alcohol consumed
df.groupby("Type of alcohol consumed").size().plot(kind="pie", autopct="%.2f%%", ax=axes[0, 0], legend=True)
axes[0, 0].set_title("Type of alcohol consumed")

# Hepatitis B infection
df.groupby("Hepatitis B infection").size().plot(kind="pie", autopct="%.2f%%", ax=axes[0, 1], legend=True)
axes[0, 1].set_title("Hepatitis B infection")

# Hepatitis C infection
df.groupby("Hepatitis C infection").size().plot(kind="pie", autopct="%.2f%%", ax=axes[1, 0], legend=True)
axes[1, 0].set_title("Hepatitis C infection")

# Diabetes Result
df.groupby("Diabetes Result").size().plot(kind="pie", autopct="%.2f%%", ax=axes[1, 1], legend=True)
axes[1, 1].set_title("Diabetes Result")



plt.tight_layout()
plt.show()

# %% [markdown]
# OUTCOME

# %%
df.groupby("Outcome").size().plot(kind="pie", autopct="%.2f%%",legend=True)
plt.title('Outcome')
plt.show()

# %% [markdown]
# # **BI-VARIATE ANALYSIS**

# %% [markdown]
# # How does age vary with outcome

# %%
sns.violinplot(y=df["Age"],x=df["Outcome"])
# Out:
# <Axes: xlabel='Outcome', ylabel='Age'>

# %% [markdown]
# Inferences from Violin Plot
#
# The violin plot shows the age distribution for patients with and without liver cirrhosis.
#
# - **Patients with Liver Cirrhosis (Yes)**:
#   - Broader age distribution with multiple peaks.
#   - Concentration around 50-60 years.
#
# - **Patients without Liver Cirrhosis (No)**:
#   - More uniform age distribution.
#   - Noticeable peak around 50 years.
#
# **Conclusion**
#
# Liver cirrhosis affects a wider range of ages, especially 50-60 years, while the age distribution for patients without cirrhosis is more consistent.

# %% [markdown]
# # How does protein influence outcome

# %%
sns.violinplot(y=df["Total Protein     (g/dl)"],x=df["Outcome"])
# Out:
# <Axes: xlabel='Outcome', ylabel='Total Protein     (g/dl)'>

# %% [markdown]
# **Total Protein Distribution:**
#
# Patients with liver cirrhosis ("yes") have a wider distribution of total protein levels ranging from approximately 3 g/dl to 9 g/dl.
#
# Patients without liver cirrhosis ("no") have a slightly narrower distribution, with total protein levels ranging from approximately 4.5 g/dl to 8 g/dl.
#
# **Median Total Protein Levels:**
#
# The median total protein level in patients with liver cirrhosis is slightly higher than in those without liver cirrhosis, as indicated by the white dot in the center of each violin.els.

# %% [markdown]
# **PROTEIN LEVEL HAS CONSIDERABLE EFFECT ON OUTCOME**

# %% [markdown]
# # How does haemoglobin affect the outcome

# %%
sns.violinplot(y=df["Hemoglobin  (g/dl)"],x=df["Outcome"])
# Out:
# <Axes: xlabel='Outcome', ylabel='Hemoglobin  (g/dl)'>

# %% [markdown]
# **Distribution:**
#
# Cirrhosis ("yes"): Hemoglobin levels range broadly from approximately 4 g/dl to 16 g/dl.
#
# No cirrhosis ("no"): Hemoglobin levels are more concentrated, ranging from about 11 g/dl to 14 g/dl.
# Median Levels:
#
# Cirrhosis: The median hemoglobin level is around 10 g/dl.
#
# No Cirrhosis: The median hemoglobin level is also around 11.5 g/dl.
#
#
# **Comparison:**
#    - Liver disease is associated with a wider range of hemoglobin levels.
#    - No liver disease shows more consistent hemoglobin levels centered around 11.5 g/dl.

# %% [markdown]
# **HAEMOGLOBIN INFLUENCES THE OUTCOME**

# %% [markdown]
# How does the distribution of gender affect the outcome

# %%
sns.countplot(data=df,x="Gender",hue="Outcome")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# **Adviceable to drop the column since it is highly biased**

# %% [markdown]
# # Scatter-Plots

# %%
import matplotlib.pyplot as plt
# Scatter plot of Age vs. Total Bilirubin
plt.scatter(df["Age"], df["Total Bilirubin    (mg/dl)"])
plt.xlabel("Age")
plt.ylabel("Total Bilirubin (mg/dl)")
plt.title("Scatter Plot of Age vs. Total Bilirubin")
plt.show()

# Scatter plot of Hemoglobin vs. Albumin
plt.scatter(df["Hemoglobin  (g/dl)"], df["Albumin   (g/dl)"])
plt.xlabel("Hemoglobin (g/dl)")
plt.ylabel("Albumin (g/dl)")
plt.title("Scatter Plot of Hemoglobin vs. Albumin")
plt.show()

# Scatter plot of Albumin vs. Globulin
plt.scatter(df["Albumin   (g/dl)"], df["Globulin  (g/dl)"])
plt.xlabel("Albumin (g/dl)")
plt.ylabel("Globulin (g/dl)")
plt.title("Scatter Plot of Albumin vs. Globulin")
plt.show()

# %% [markdown]
# ### Inferences from the Scatter Plot of Albumin vs. Globulin:
#
# 1. **No Strong Correlation**:
#    - The scatter plot indicates no strong linear relationship between albumin and globulin levels. The data points are widely scattered, suggesting that variations in albumin levels do not directly predict changes in globulin levels.
#
# 2. **Range of Values**:
#    - Most albumin levels fall within the range of 2.0 to 4.0 g/dl, while globulin levels range from 2.0 to 5.0 g/dl. There are some outliers with higher globulin levels up to 6.0 g/dl and albumin levels up to 4.5 g/dl, indicating diverse liver function profiles among the patients.

# %% [markdown]
# # **MULTI-VARIATE ANALYSIS**

# %%
df1=df.copy()

# %% [markdown]
# Dropping all the unnecessary columns

# %%
df1.drop(columns=["Gender",'TCH','TG','LDL','RBC  (million cells/microliter)','MCH  (picograms/cell)','MCHC  (grams/deciliter)','Total Count','Eosinophils   (%)','Globulin  (g/dl)'],inplace=True)

# %% [markdown]
# Correlation Matrix

# %%
df1.corr(numeric_only=True)
# Out:
#                                                      Age  \
# Age                                             1.000000
# Duration of alcohol consumption(years)          0.504880
# Quantity of alcohol consumption (quarters/day) -0.014838
# HDL                                             0.027021
# Hemoglobin  (g/dl)                              0.005643
# PCV  (%)                                        0.097591
# MCV   (femtoliters/cell)                        0.044536
# Polymorphs  (%)                                 0.102051
# Lymphocytes  (%)                               -0.051998
# Monocytes   (%)                                -0.017115
# Basophils  (%)                                 -0.293272
# Platelet Count  (lakhs/mm)                      0.071371
# Total Bilirubin    (mg/dl)                      0.111111
# Direct    (mg/dl)                               0.056810
# Indirect     (mg/dl)                            0.241744
# Total Protein     (g/dl)                        0.061647
# Albumin   (g/dl)                               -0.025472
# A/G Ratio                                      -0.072670
# AL.Phosphatase      (U/L)                       0.117445
# SGOT/AST      (U/L)                             0.051609
# SGPT/ALT (U/L)                                  0.104097
#
#                                                 Duration of alcohol consumption(years)  \
# Age                                                                           0.504880
# Duration of alcohol consumption(years)                                        1.000000
# Quantity of alcohol consumption (quarters/day)                                0.013511
# HDL                                                                           0.102488
# Hemoglobin  (g/dl)                                                           -0.066525
# PCV  (%)                                                                     -0.003214
# MCV   (femtoliters/cell)                                                      0.275167
# Polymorphs  (%)                                                               0.263651
# Lymphocytes  (%)                                                             -0.363089
# Monocytes   (%)                                                               0.199293
# Basophils  (%)                                                               -0.107265
# Platelet Count  (lakhs/mm)                                                   -0.093403
# Total Bilirubin    (mg/dl)                                                   -0.180130
# Direct    (mg/dl)                                                            -0.258064
# Indirect     (mg/dl)                                                          0.098370
# Total Protein     (g/dl)                                                     -0.127660
# Albumin   (g/dl)                                                             -0.266224
# A/G Ratio                                                                    -0.150173
# AL.Phosphatase      (U/L)                                                     0.312834
# SGOT/AST      (U/L)                                                           0.305667
# SGPT/ALT (U/L)                                                                0.220968
#
#                                                 Quantity of alcohol consumption (quarters/day)  \
# Age                                                                                  -0.014838
# Duration of alcohol consumption(years)                                                0.013511
# Quantity of alcohol consumption (quarters/day)                                        1.000000
# HDL                                                                                   0.087929
# Hemoglobin  (g/dl)                                                                   -0.028515
# PCV  (%)                                                                             -0.106242
# MCV   (femtoliters/cell)                                                             -0.003966
# Polymorphs  (%)                                                                      -0.001482
# Lymphocytes  (%)                                                                      0.102467
# Monocytes   (%)                                                                      -0.043940
# Basophils  (%)                                                                        0.139578
# Platelet Count  (lakhs/mm)                                                            0.111797
# Total Bilirubin    (mg/dl)                                                           -0.058668
# Direct    (mg/dl)                                                                    -0.070019
# Indirect     (mg/dl)                                                                  0.068496
# Total Protein     (g/dl)                                                             -0.176093
# Albumin   (g/dl)                                                                     -0.004464
# A/G Ratio                                                                             0.128809
# AL.Phosphatase      (U/L)                                                            -0.094731
# SGOT/AST      (U/L)                                                                  -0.062926
# SGPT/ALT (U/L)                                                                       -0.080740
#
#                                                      HDL  Hemoglobin  (g/dl)  \
# Age                                             0.027021            0.005643
# Duration of alcohol consumption(years)          0.102488           -0.066525
# Quantity of alcohol consumption (quarters/day)  0.087929           -0.028515
# HDL                                             1.000000           -0.031386
# Hemoglobin  (g/dl)                             -0.031386            1.000000
# PCV  (%)                                       -0.042923           -0.006746
# MCV   (femtoliters/cell)                       -0.003529           -0.026800
# Polymorphs  (%)                                -0.170594           -0.023490
# Lymphocytes  (%)                               -0.014607            0.010444
# Monocytes   (%)                                 0.114945           -0.008577
# Basophils  (%)                                 -0.072160            0.052103
# Platelet Count  (lakhs/mm)                     -0.145335            0.021393
# Total Bilirubin    (mg/dl)                      0.038456           -0.046225
# Direct    (mg/dl)                              -0.001202            0.015173
# Indirect     (mg/dl)                            0.038557           -0.019270
# Total Protein     (g/dl)                        0.038159            0.036043
# Albumin   (g/dl)                               -0.181625            0.069044
# A/G Ratio                                      -0.173873            0.040801
# AL.Phosphatase      (U/L)                      -0.143857           -0.009615
# SGOT/AST      (U/L)                             0.071819           -0.009007
# SGPT/ALT (U/L)                                  0.064580           -0.046745
#
#                                                 PCV  (%)  \
# Age                                             0.097591
# Duration of alcohol consumption(years)         -0.003214
# Quantity of alcohol consumption (quarters/day) -0.106242
# HDL                                            -0.042923
# Hemoglobin  (g/dl)                             -0.006746
# PCV  (%)                                        1.000000
# MCV   (femtoliters/cell)                       -0.215279
# Polymorphs  (%)                                -0.061485
# Lymphocytes  (%)                                0.099383
# Monocytes   (%)                                -0.014051
# Basophils  (%)                                 -0.296938
# Platelet Count  (lakhs/mm)                      0.260573
# Total Bilirubin    (mg/dl)                      0.006346
# Direct    (mg/dl)                               0.124041
# Indirect     (mg/dl)                           -0.147214
# Total Protein     (g/dl)                        0.310499
# Albumin   (g/dl)                                0.348276
# A/G Ratio                                       0.120090
# AL.Phosphatase      (U/L)                       0.003518
# SGOT/AST      (U/L)                            -0.152265
# SGPT/ALT (U/L)                                 -0.186766
#
#                                                 MCV   (femtoliters/cell)  \
# Age                                                             0.044536
# Duration of alcohol consumption(years)                          0.275167
# Quantity of alcohol consumption (quarters/day)                 -0.003966
# HDL                                                            -0.003529
# Hemoglobin  (g/dl)                                             -0.026800
# PCV  (%)                                                       -0.215279
# MCV   (femtoliters/cell)                                        1.000000
# Polymorphs  (%)                                                 0.096923
# Lymphocytes  (%)                                               -0.223638
# Monocytes   (%)                                                 0.114024
# Basophils  (%)                                                  0.119891
# Platelet Count  (lakhs/mm)                                      0.029725
# Total Bilirubin    (mg/dl)                                     -0.301073
# Direct    (mg/dl)                                              -0.408698
# Indirect     (mg/dl)                                           -0.007832
# Total Protein     (g/dl)                                       -0.193946
# Albumin   (g/dl)                                               -0.129655
# A/G Ratio                                                       0.021159
# AL.Phosphatase      (U/L)                                      -0.043319
# SGOT/AST      (U/L)                                             0.278110
# SGPT/ALT (U/L)                                                  0.235697
#
#                                                 Polymorphs  (%)   \
# Age                                                     0.102051
# Duration of alcohol consumption(years)                  0.263651
# Quantity of alcohol consumption (quarters/day)         -0.001482
# HDL                                                    -0.170594
# Hemoglobin  (g/dl)                                     -0.023490
# PCV  (%)                                               -0.061485
# MCV   (femtoliters/cell)                                0.096923
# Polymorphs  (%)                                         1.000000
# Lymphocytes  (%)                                       -0.479791
# Monocytes   (%)                                        -0.128826
# Basophils  (%)                                         -0.069653
# Platelet Count  (lakhs/mm)                             -0.056582
# Total Bilirubin    (mg/dl)                              0.096292
# Direct    (mg/dl)                                      -0.048245
# Indirect     (mg/dl)                                    0.163071
# Total Protein     (g/dl)                               -0.079210
# Albumin   (g/dl)                                       -0.153799
# A/G Ratio                                              -0.044456
# AL.Phosphatase      (U/L)                               0.047370
# SGOT/AST      (U/L)                                    -0.100152
# SGPT/ALT (U/L)                                          0.067920
#
#                                                 Lymphocytes  (%)  \
# Age                                                    -0.051998
# Duration of alcohol consumption(years)                 -0.363089
# Quantity of alcohol consumption (quarters/day)          0.102467
# HDL                                                    -0.014607
# Hemoglobin  (g/dl)                                      0.010444
# PCV  (%)                                                0.099383
# MCV   (femtoliters/cell)                               -0.223638
# Polymorphs  (%)                                        -0.479791
# Lymphocytes  (%)                                        1.000000
# Monocytes   (%)                                        -0.535430
# Basophils  (%)                                         -0.180878
# Platelet Count  (lakhs/mm)                              0.382883
# Total Bilirubin    (mg/dl)                              0.087118
# Direct    (mg/dl)                                       0.220090
# Indirect     (mg/dl)                                   -0.092456
# Total Protein     (g/dl)                                0.180241
# Albumin   (g/dl)                                        0.387191
# A/G Ratio                                               0.197401
# AL.Phosphatase      (U/L)                               0.006548
# SGOT/AST      (U/L)                                    -0.215464
# SGPT/ALT (U/L)                                         -0.283448
#
#                                                 Monocytes   (%)  ...  \
# Age                                                   -0.017115  ...
# Duration of alcohol consumption(years)                 0.199293  ...
# Quantity of alcohol consumption (quarters/day)        -0.043940  ...
# HDL                                                    0.114945  ...
# Hemoglobin  (g/dl)                                    -0.008577  ...
# PCV  (%)                                              -0.014051  ...
# MCV   (femtoliters/cell)                               0.114024  ...
# Polymorphs  (%)                                       -0.128826  ...
# Lymphocytes  (%)                                      -0.535430  ...
# Monocytes   (%)                                        1.000000  ...
# Basophils  (%)                                         0.334910  ...
# Platelet Count  (lakhs/mm)                            -0.393730  ...
# Total Bilirubin    (mg/dl)                            -0.153523  ...
# Direct    (mg/dl)                                     -0.162125  ...
# Indirect     (mg/dl)                                  -0.072557  ...
# Total Protein     (g/dl)                               0.005474  ...
# Albumin   (g/dl)                                      -0.344347  ...
# A/G Ratio                                             -0.391991  ...
# AL.Phosphatase      (U/L)                              0.009877  ...
# SGOT/AST      (U/L)                                    0.218727  ...
# SGPT/ALT (U/L)                                         0.124288  ...
#
#                                                 Platelet Count  (lakhs/mm)  \
# Age                                                               0.071371
# Duration of alcohol consumption(years)                           -0.093403
# Quantity of alcohol consumption (quarters/day)                    0.111797
# HDL                                                              -0.145335
# Hemoglobin  (g/dl)                                                0.021393
# PCV  (%)                                                          0.260573
# MCV   (femtoliters/cell)                                          0.029725
# Polymorphs  (%)                                                  -0.056582
# Lymphocytes  (%)                                                  0.382883
# Monocytes   (%)                                                  -0.393730
# Basophils  (%)                                                   -0.221665
# Platelet Count  (lakhs/mm)                                        1.000000
# Total Bilirubin    (mg/dl)                                       -0.215804
# Direct    (mg/dl)                                                -0.134197
# Indirect     (mg/dl)                                             -0.164128
# Total Protein     (g/dl)                                          0.165374
# Albumin   (g/dl)                                                  0.530975
# A/G Ratio                                                         0.483932
# AL.Phosphatase      (U/L)                                        -0.119343
# SGOT/AST      (U/L)                                               0.037232
# SGPT/ALT (U/L)                                                    0.025080
#
#                                                 Total Bilirubin    (mg/dl)  \
# Age                                                               0.111111
# Duration of alcohol consumption(years)                           -0.180130
# Quantity of alcohol consumption (quarters/day)                   -0.058668
# HDL                                                               0.038456
# Hemoglobin  (g/dl)                                               -0.046225
# PCV  (%)                                                          0.006346
# MCV   (femtoliters/cell)                                         -0.301073
# Polymorphs  (%)                                                   0.096292
# Lymphocytes  (%)                                                  0.087118
# Monocytes   (%)                                                  -0.153523
# Basophils  (%)                                                   -0.244269
# Platelet Count  (lakhs/mm)                                       -0.215804
# Total Bilirubin    (mg/dl)                                        1.000000
# Direct    (mg/dl)                                                 0.860661
# Indirect     (mg/dl)                                              0.525814
# Total Protein     (g/dl)                                          0.217946
# Albumin   (g/dl)                                                 -0.060116
# A/G Ratio                                                        -0.247892
# AL.Phosphatase      (U/L)                                         0.030080
# SGOT/AST      (U/L)                                              -0.345566
# SGPT/ALT (U/L)                                                   -0.188954
#
#                                                 Direct    (mg/dl)  \
# Age                                                      0.056810
# Duration of alcohol consumption(years)                  -0.258064
# Quantity of alcohol consumption (quarters/day)          -0.070019
# HDL                                                     -0.001202
# Hemoglobin  (g/dl)                                       0.015173
# PCV  (%)                                                 0.124041
# MCV   (femtoliters/cell)                                -0.408698
# Polymorphs  (%)                                         -0.048245
# Lymphocytes  (%)                                         0.220090
# Monocytes   (%)                                         -0.162125
# Basophils  (%)                                          -0.336547
# Platelet Count  (lakhs/mm)                              -0.134197
# Total Bilirubin    (mg/dl)                               0.860661
# Direct    (mg/dl)                                        1.000000
# Indirect     (mg/dl)                                     0.226658
# Total Protein     (g/dl)                                 0.357692
# Albumin   (g/dl)                                         0.085884
# A/G Ratio                                               -0.171140
# AL.Phosphatase      (U/L)                                0.064650
# SGOT/AST      (U/L)                                     -0.372329
# SGPT/ALT (U/L)                                          -0.226715
#
#                                                 Indirect     (mg/dl)  \
# Age                                                         0.241744
# Duration of alcohol consumption(years)                      0.098370
# Quantity of alcohol consumption (quarters/day)              0.068496
# HDL                                                         0.038557
# Hemoglobin  (g/dl)                                         -0.019270
# PCV  (%)                                                   -0.147214
# MCV   (femtoliters/cell)                                   -0.007832
# Polymorphs  (%)                                             0.163071
# Lymphocytes  (%)                                           -0.092456
# Monocytes   (%)                                            -0.072557
# Basophils  (%)                                              0.084370
# Platelet Count  (lakhs/mm)                                 -0.164128
# Total Bilirubin    (mg/dl)                                  0.525814
# Direct    (mg/dl)                                           0.226658
# Indirect     (mg/dl)                                        1.000000
# Total Protein     (g/dl)                                   -0.214989
# Albumin   (g/dl)                                           -0.202710
# A/G Ratio                                                  -0.194788
# AL.Phosphatase      (U/L)                                  -0.036866
# SGOT/AST      (U/L)                                        -0.115588
# SGPT/ALT (U/L)                                             -0.119638
#
#                                                 Total Protein     (g/dl)  \
# Age                                                             0.061647
# Duration of alcohol consumption(years)                         -0.127660
# Quantity of alcohol consumption (quarters/day)                 -0.176093
# HDL                                                             0.038159
# Hemoglobin  (g/dl)                                              0.036043
# PCV  (%)                                                        0.310499
# MCV   (femtoliters/cell)                                       -0.193946
# Polymorphs  (%)                                                -0.079210
# Lymphocytes  (%)                                                0.180241
# Monocytes   (%)                                                 0.005474
# Basophils  (%)                                                 -0.251765
# Platelet Count  (lakhs/mm)                                      0.165374
# Total Bilirubin    (mg/dl)                                      0.217946
# Direct    (mg/dl)                                               0.357692
# Indirect     (mg/dl)                                           -0.214989
# Total Protein     (g/dl)                                        1.000000
# Albumin   (g/dl)                                                0.533836
# A/G Ratio                                                       0.021265
# AL.Phosphatase      (U/L)                                       0.021523
# SGOT/AST      (U/L)                                            -0.312623
# SGPT/ALT (U/L)                                                 -0.233307
#
#                                                 Albumin   (g/dl)  A/G Ratio  \
# Age                                                    -0.025472  -0.072670
# Duration of alcohol consumption(years)                 -0.266224  -0.150173
# Quantity of alcohol consumption (quarters/day)         -0.004464   0.128809
# HDL                                                    -0.181625  -0.173873
# Hemoglobin  (g/dl)                                      0.069044   0.040801
# PCV  (%)                                                0.348276   0.120090
# MCV   (femtoliters/cell)                               -0.129655   0.021159
# Polymorphs  (%)                                        -0.153799  -0.044456
# Lymphocytes  (%)                                        0.387191   0.197401
# Monocytes   (%)                                        -0.344347  -0.391991
# Basophils  (%)                                         -0.162711  -0.001568
# Platelet Count  (lakhs/mm)                              0.530975   0.483932
# Total Bilirubin    (mg/dl)                             -0.060116  -0.247892
# Direct    (mg/dl)                                       0.085884  -0.171140
# Indirect     (mg/dl)                                   -0.202710  -0.194788
# Total Protein     (g/dl)                                0.533836   0.021265
# Albumin   (g/dl)                                        1.000000   0.764460
# A/G Ratio                                               0.764460   1.000000
# AL.Phosphatase      (U/L)                               0.041297  -0.068055
# SGOT/AST      (U/L)                                    -0.195451   0.053864
# SGPT/ALT (U/L)                                         -0.181352   0.066216
#
#                                                 AL.Phosphatase      (U/L)  \
# Age                                                              0.117445
# Duration of alcohol consumption(years)                           0.312834
# Quantity of alcohol consumption (quarters/day)                  -0.094731
# HDL                                                             -0.143857
# Hemoglobin  (g/dl)                                              -0.009615
# PCV  (%)                                                         0.003518
# MCV   (femtoliters/cell)                                        -0.043319
# Polymorphs  (%)                                                  0.047370
# Lymphocytes  (%)                                                 0.006548
# Monocytes   (%)                                                  0.009877
# Basophils  (%)                                                  -0.081563
# Platelet Count  (lakhs/mm)                                      -0.119343
# Total Bilirubin    (mg/dl)                                       0.030080
# Direct    (mg/dl)                                                0.064650
# Indirect     (mg/dl)                                            -0.036866
# Total Protein     (g/dl)                                         0.021523
# Albumin   (g/dl)                                                 0.041297
# A/G Ratio                                                       -0.068055
# AL.Phosphatase      (U/L)                                        1.000000
# SGOT/AST      (U/L)                                              0.053157
# SGPT/ALT (U/L)                                                   0.001771
#
#                                                 SGOT/AST      (U/L)  \
# Age                                                        0.051609
# Duration of alcohol consumption(years)                     0.305667
# Quantity of alcohol consumption (quarters/day)            -0.062926
# HDL                                                        0.071819
# Hemoglobin  (g/dl)                                        -0.009007
# PCV  (%)                                                  -0.152265
# MCV   (femtoliters/cell)                                   0.278110
# Polymorphs  (%)                                           -0.100152
# Lymphocytes  (%)                                          -0.215464
# Monocytes   (%)                                            0.218727
# Basophils  (%)                                             0.067905
# Platelet Count  (lakhs/mm)                                 0.037232
# Total Bilirubin    (mg/dl)                                -0.345566
# Direct    (mg/dl)                                         -0.372329
# Indirect     (mg/dl)                                      -0.115588
# Total Protein     (g/dl)                                  -0.312623
# Albumin   (g/dl)                                          -0.195451
# A/G Ratio                                                  0.053864
# AL.Phosphatase      (U/L)                                  0.053157
# SGOT/AST      (U/L)                                        1.000000
# SGPT/ALT (U/L)                                             0.741731
#
#                                                 SGPT/ALT (U/L)
# Age                                                   0.104097
# Duration of alcohol consumption(years)                0.220968
# Quantity of alcohol consumption (quarters/day)       -0.080740
# HDL                                                   0.064580
# Hemoglobin  (g/dl)                                   -0.046745
# PCV  (%)                                             -0.186766
# MCV   (femtoliters/cell)                              0.235697
# Polymorphs  (%)                                       0.067920
# Lymphocytes  (%)                                     -0.283448
# Monocytes   (%)                                       0.124288
# Basophils  (%)                                       -0.018377
# Platelet Count  (lakhs/mm)                            0.025080
# Total Bilirubin    (mg/dl)                           -0.188954
# Direct    (mg/dl)                                    -0.226715
# Indirect     (mg/dl)                                 -0.119638
# Total Protein     (g/dl)                             -0.233307
# Albumin   (g/dl)                                     -0.181352
# A/G Ratio                                             0.066216
# AL.Phosphatase      (U/L)                             0.001771
# SGOT/AST      (U/L)                                   0.741731
# SGPT/ALT (U/L)                                        1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# Heatmap

# %%
sns.heatmap(df1.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Printing all those columns with high coorelation

# %%
correlation_matrix = df1.corr(numeric_only=True)
high_correlation_pairs = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i + 1, len(correlation_matrix.columns)):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            high_correlation_pairs.append((correlation_matrix.columns[i], correlation_matrix.columns[j], correlation_matrix.iloc[i, j]))
for pair in high_correlation_pairs:
    print(f"{pair[0]} and {pair[1]}: {pair[2] * 100:.2f}%")
# Out:
# Total Bilirubin    (mg/dl) and Direct    (mg/dl): 86.07%

# %% [markdown]
# Since both of them have high coorelation we drop Direct

# %% [markdown]
# **EDA COMPLETED AND DATA HAS BEEN ANALYSED**

# %% [markdown]
# # DESCRIPTIVE ANALYSIS

# %%
df.describe()
# Out:
#               Age  Duration of alcohol consumption(years)  \
# count  931.000000                              931.000000
# mean    50.588614                               20.552632
# std      8.747285                                7.978730
# min     32.000000                                4.000000
# 25%     44.000000                               15.000000
# 50%     50.000000                               20.000000
# 75%     57.000000                               26.000000
# max     76.500000                               42.500000
#
#        Quantity of alcohol consumption (quarters/day)         TCH          TG  \
# count                                      931.000000  931.000000  931.000000
# mean                                         2.195489  195.816696  161.030075
# std                                          0.817103   10.909775   20.408020
# min                                          1.000000  175.000000   86.000000
# 25%                                          2.000000  190.000000  160.000000
# 50%                                          2.000000  197.423932  161.000000
# 75%                                          3.000000  200.000000  170.000000
# max                                          4.500000  215.000000  206.000000
#
#               LDL         HDL  Hemoglobin  (g/dl)    PCV  (%)  \
# count  931.000000  931.000000          931.000000  931.000000
# mean   106.309345   34.914618           10.266305   33.900873
# std     17.220609    3.262292            1.887182    5.307312
# min     49.000000   28.500000            5.250000   20.500000
# 25%    104.000000   33.000000            9.000000   31.000000
# 50%    106.000000   35.516464           10.000000   35.000000
# 75%    109.000000   36.000000           11.500000   38.000000
# max    220.000000   40.500000           15.250000   48.000000
#
#        RBC  (million cells/microliter)  ...  Total Bilirubin    (mg/dl)  \
# count                     9.310000e+02  ...                  931.000000
# mean                      3.386582e+00  ...                    6.118582
# std                       1.110820e-14  ...                    2.195534
# min                       3.386582e+00  ...                    0.750000
# 25%                       3.386582e+00  ...                    4.800000
# 50%                       3.386582e+00  ...                    6.000000
# 75%                       3.386582e+00  ...                    7.500000
# max                       3.386582e+00  ...                   11.000000
#
#        Direct    (mg/dl)  Indirect     (mg/dl)  Total Protein     (g/dl)  \
# count         931.000000            931.000000                931.000000
# mean            3.704834              2.423035                  5.595907
# std             1.573631              0.937483                  1.265447
# min             0.800000              0.500000                  2.900000
# 25%             2.700000              2.000000                  5.000000
# 50%             3.600000              2.400000                  6.000000
# 75%             4.200000              3.000000                  6.400000
# max             6.450000              4.500000                  8.300000
#
#        Albumin   (g/dl)  Globulin  (g/dl)   A/G Ratio  \
# count        931.000000        931.000000  931.000000
# mean           2.529510          3.225369    0.855725
# std            0.853937          0.995112    0.396936
# min            0.900000          1.000000    0.250000
# 25%            2.000000          2.500000    0.540000
# 50%            2.500000          3.100000    0.780000
# 75%            3.000000          4.000000    1.000000
# max            4.500000          6.000000    1.690000
#
#        AL.Phosphatase      (U/L)  SGOT/AST      (U/L)  SGPT/ALT (U/L)
# count                 931.000000           931.000000      931.000000
# mean                  132.292207            80.383459       59.821697
# std                    27.271596            27.019867       25.076247
# min                    56.000000            32.000000       23.000000
# 25%                   110.000000            59.000000       41.000000
# 50%                   130.000000            74.000000       49.000000
# 75%                   150.000000            96.000000       76.000000
# max                   206.000000           151.500000      128.500000
#
# [8 rows x 30 columns]

# %% [markdown]
# Splitting the data

# %%
df.mean(axis=0,numeric_only=True)
# Out:
# Age                                                 50.588614
# Duration of alcohol consumption(years)              20.552632
# Quantity of alcohol consumption (quarters/day)       2.195489
# TCH                                                195.816696
# TG                                                 161.030075
# LDL                                                106.309345
# HDL                                                 34.914618
# Hemoglobin  (g/dl)                                  10.266305
# PCV  (%)                                            33.900873
# RBC  (million cells/microliter)                      3.386582
# MCV   (femtoliters/cell)                            87.434408
# MCH  (picograms/cell)                               30.512111
# MCHC  (grams/deciliter)                             31.907273
# Total Count                                       8149.711704
# Polymorphs  (%)                                     66.932331
# Lymphocytes  (%)                                    26.006445
# Monocytes   (%)                                      3.633432
# Eosinophils   (%)                                    2.269037
# Basophils  (%)                                       0.469048
# Platelet Count  (lakhs/mm)                           1.441933
# Total Bilirubin    (mg/dl)                           6.118582
# Direct    (mg/dl)                                    3.704834
# Indirect     (mg/dl)                                 2.423035
# Total Protein     (g/dl)                             5.595907
# Albumin   (g/dl)                                     2.529510
# Globulin  (g/dl)                                     3.225369
# A/G Ratio                                            0.855725
# AL.Phosphatase      (U/L)                          132.292207
# SGOT/AST      (U/L)                                 80.383459
# SGPT/ALT (U/L)                                      59.821697
# dtype: float64

# %%
import pandas as pd
import random

# Select rows where Outcome is "NO"
df_no_outcome = df[df["Outcome"] == "no"]

# Check if df_no_outcome is empty and handle it accordingly
if df_no_outcome.empty:
    print("No rows found with 'NO' outcome. Cannot generate synthetic data.")
else:
    # Generate synthetic rows based on existing "NO" outcome rows
    synthetic_rows = []
    num_synthetic_samples = 300  # Number of synthetic samples to generate

    for _ in range(num_synthetic_samples):
        # Randomly select a row from df_no_outcome
        selected_row = df_no_outcome.sample(n=1).iloc[0]

        # Create a new row with random values based on the selected row
        synthetic_row = selected_row.copy()
        for column in df_no_outcome.columns:
            if df_no_outcome[column].dtype in ["int64", "float64"]:
                # Add noise within a 10% range of the selected row's value
                noise_factor = 0.1 * selected_row[column]
                synthetic_row[column] = random.uniform(selected_row[column] - noise_factor, selected_row[column] + noise_factor)
            elif df_no_outcome[column].dtype == "object":
                synthetic_row[column] = random.choice(df_no_outcome[column].unique())

        synthetic_rows.append(synthetic_row)

    # Convert synthetic rows to a DataFrame and append to the original DataFrame
    synthetic_df = pd.DataFrame(synthetic_rows, columns=df_no_outcome.columns)
    df = pd.concat([df, synthetic_df], ignore_index=True)

# %%
X = df.drop('Outcome', axis=1)
y = df['Outcome']

# %% [markdown]
# Encoding the data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in X.columns:
  if X[i].dtype == 'object':
    X[i] = le.fit_transform(X[i])

# %%
y_encoded =(le.fit_transform(y))

# %%
X.head()
# Out:
#     Age  Gender  Duration of alcohol consumption(years)  \
# 0  55.0       1                                    12.0
# 1  55.0       1                                    12.0
# 2  55.0       1                                    12.0
# 3  55.0       1                                    12.0
# 4  55.0       0                                    12.0
#
#    Quantity of alcohol consumption (quarters/day)  Type of alcohol consumed  \
# 0                                             2.0                         1
# 1                                             2.0                         1
# 2                                             2.0                         1
# 3                                             2.0                         1
# 4                                             2.0                         1
#
#    Hepatitis B infection  Hepatitis C infection  Diabetes Result  \
# 0                      0                      0                1
# 1                      0                      0                1
# 2                      0                      0                1
# 3                      0                      0                0
# 4                      0                      0                1
#
#    Blood pressure (mmhg)  Obesity  ...  Direct    (mg/dl)  \
# 0                     32        1  ...                4.0
# 1                     32        1  ...                4.0
# 2                     32        0  ...                4.0
# 3                     32        0  ...                4.0
# 4                     32        0  ...                4.0
#
#    Indirect     (mg/dl)  Total Protein     (g/dl)  Albumin   (g/dl)  \
# 0                   3.0                       6.0               3.0
# 1                   3.0                       6.0               3.0
# 2                   3.0                       6.0               3.0
# 3                   3.0                       6.0               3.0
# 4                   3.0                       6.0               3.0
#
#    Globulin  (g/dl)  A/G Ratio  AL.Phosphatase      (U/L)  \
# 0               4.0       0.75                      150.0
# 1               4.0       0.75                      150.0
# 2               4.0       0.75                      150.0
# 3               4.0       0.75                      150.0
# 4               4.0       0.75                      150.0
#
#    SGOT/AST      (U/L)  SGPT/ALT (U/L)  USG Abdomen (diffuse liver or  not)
# 0                 56.0            34.0                                    0
# 1                 56.0            34.0                                    0
# 2                 56.0            34.0                                    0
# 3                 56.0            34.0                                    0
# 4                 56.0            34.0                                    0
#
# [5 rows x 39 columns]

# %% [markdown]
# # Feature importance

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100)
model.fit(X, y)
importances = model.feature_importances_

# Print feature importances
for feature, importance in zip(X.columns, importances):
    print(f"{feature}: {importance:.4f}")
# Out:
# Age: 0.0000
# Gender: 0.0000
# Duration of alcohol consumption(years): 0.1441
# Quantity of alcohol consumption (quarters/day): 0.0204
# Type of alcohol consumed: 0.0032
# Hepatitis B infection: 0.0000
# Hepatitis C infection: 0.0000
# Diabetes Result: 0.0061
# Blood pressure (mmhg): 0.0015
# Obesity: 0.0064
# Family history of cirrhosis/ hereditary: 0.0000
# TCH: 0.0000
# TG: 0.0001
# LDL: 0.0019
# HDL: 0.0000
# Hemoglobin  (g/dl): 0.0005
# PCV  (%): 0.0001
# RBC  (million cells/microliter): 0.0346
# MCV   (femtoliters/cell): 0.0001
# MCH  (picograms/cell): 0.0127
# MCHC  (grams/deciliter): 0.0254
# Total Count: 0.0005
# Polymorphs  (%) : 0.0030
# Lymphocytes  (%): 0.0043
# Monocytes   (%): 0.0000
# Eosinophils   (%): 0.0000
# Basophils  (%): 0.0013
# Platelet Count  (lakhs/mm): 0.0317
# Total Bilirubin    (mg/dl): 0.2199
# Direct    (mg/dl): 0.1581
# Indirect     (mg/dl): 0.0153
# Total Protein     (g/dl): 0.0013
# Albumin   (g/dl): 0.0482
# Globulin  (g/dl): 0.0033
# A/G Ratio: 0.0602
# AL.Phosphatase      (U/L): 0.0046
# SGOT/AST      (U/L): 0.0537
# SGPT/ALT (U/L): 0.0041
# USG Abdomen (diffuse liver or  not): 0.1334

# %% [markdown]
# **INFERENCE**
#
# In the given output of feature importances from the RandomForestClassifier model, features have an importance score of 0 or very less. These features are:
#
# Gender
#
# Hepatitis B infection
#
# Hepatitis C infection
#
# Family history of cirrhosis/ hereditary
#
# TCH
#
# TG
#
# LDL
#
# HDL
#
# MCV (femtoliters/cell)

# %% [markdown]
# DROPPING ALL UNECESSARY COLUMNS

# %%
drop_col=["Type of alcohol consumed","Gender","Direct    (mg/dl)","MCH  (picograms/cell)","MCHC  (grams/deciliter)","Obesity","Family history of cirrhosis/ hereditary","TCH","LDL","HDL","MCV   (femtoliters/cell)","Total Count","Monocytes   (%)","Basophils  (%)","SGOT/AST      (U/L)","SGPT/ALT (U/L)","MCHC  (grams/deciliter)","RBC  (million cells/microliter)","Quantity of alcohol consumption (quarters/day): 0.0110","Eosinophils   (%)","TG","Hepatitis B infection","Hepatitis C infection","Duration of alcohol consumption(years)","Total Bilirubin    (mg/dl)"]

# %%
#drop_col=["Age","Gender","Hepatitis B infection","Hepatitis C infection","Diabetes Result","Blood pressure (mmhg)","Obesity","Family history of cirrhosis/ hereditary","TCH","TG","LDL","HDL","RBC  (million cells/microliter)","MCV   (femtoliters/cell)","MCH  (picograms/cell)","Total Count","Monocytes   (%)","Eosinophils   (%)","Basophils  (%)","Type of alcohol consumed","MCHC  (grams/deciliter)","Total Bilirubin    (mg/dl)","Duration of alcohol consumption(years)"]

# %%
for col in drop_col:
  if col in X.columns:
    X.drop(columns=[col],inplace=True)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100)
model.fit(X, y)
importances = model.feature_importances_

# Print feature importances
for feature, importance in zip(X.columns, importances):
    print(f"{feature}: {importance:.4f}")
# Out:
# Age: 0.0020
# Quantity of alcohol consumption (quarters/day): 0.0534
# Diabetes Result: 0.0618
# Blood pressure (mmhg): 0.0213
# Hemoglobin  (g/dl): 0.0123
# PCV  (%): 0.0045
# Polymorphs  (%) : 0.0330
# Lymphocytes  (%): 0.0015
# Platelet Count  (lakhs/mm): 0.0730
# Indirect     (mg/dl): 0.0199
# Total Protein     (g/dl): 0.0139
# Albumin   (g/dl): 0.1216
# Globulin  (g/dl): 0.0110
# A/G Ratio: 0.0949
# AL.Phosphatase      (U/L): 0.0439
# USG Abdomen (diffuse liver or  not): 0.4320

# %% [markdown]
# Splitting the data into Train and Test

# %%
from sklearn.model_selection import train_test_split, cross_val_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %% [markdown]
# Since the outcome is highly skewed we oversample the data

# %%
from imblearn.over_sampling import RandomOverSampler
os=RandomOverSampler(random_state=0)
X_resampled, y_resampled = os.fit_resample(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 from imblearn.over_sampling import RandomOverSampler
#       2 os=RandomOverSampler(random_state=0)
#       3 X_resampled, y_resampled = os.fit_resample(X_train, y_train)
#
# File c:\Users\aniki\anaconda3\Lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# File c:\Users\aniki\anaconda3\Lib\site-packages\imblearn\combine\__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File c:\Users\aniki\anaconda3\Lib\site-packages\imblearn\combine\_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File c:\Users\aniki\anaconda3\Lib\site-packages\imblearn\base.py:21
#      18 from sklearn.utils.multiclass import check_classification_targets
#      20 from .utils import check_sampling_strategy, check_target_type
# ---> 21 from .utils._param_validation import validate_parameter_constraints
#      22 from .utils._validation import ArraysTransformer
#      25 class SamplerMixin(BaseEstimator, metaclass=ABCMeta):
#
# File c:\Users\aniki\anaconda3\Lib\site-packages\imblearn\utils\_param_validation.py:908
#     906 from sklearn.utils._param_validation import generate_valid_param  # noqa
#     907 from sklearn.utils._param_validation import validate_parameter_constraints  # noqa
# --> 908 from sklearn.utils._param_validation import (
#     909     HasMethods,
#     910     Hidden,
#     911     Interval,
#     912     Options,
#     913     StrOptions,
#     914     _ArrayLikes,
#     915     _Booleans,
#     916     _Callables,
#     917     _CVObjects,
#     918     _InstancesOf,
#     919     _IterablesNotString,
#     920     _MissingValues,
#     921     _NoneConstraint,
#     922     _PandasNAConstraint,
#     923     _RandomStates,
#     924     _SparseMatrices,
#     925     _VerboseHelper,
#     926     make_constraint,
#     927     validate_params,
#     928 )
#
# ImportError: cannot import name '_MissingValues' from 'sklearn.utils._param_validation' (c:\Users\aniki\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py)

# %%
X_resampled.columns
# Out:
# Index(['Age', 'Quantity of alcohol consumption (quarters/day)',
#        'Diabetes Result', 'Blood pressure (mmhg)', 'Hemoglobin  (g/dl)',
#        'PCV  (%)', 'Polymorphs  (%) ', 'Lymphocytes  (%)',
#        'Platelet Count  (lakhs/mm)', 'Indirect     (mg/dl)',
#        'Total Protein     (g/dl)', 'Albumin   (g/dl)', 'Globulin  (g/dl)',
#        'A/G Ratio', 'AL.Phosphatase      (U/L)',
#        'USG Abdomen (diffuse liver or  not)'],
#       dtype='object')

# %% [markdown]
# Both the outcomes are well balanced now

# %%
y_resampled_series = pd.Series(y_resampled)

y_resampled_series.value_counts()
# Out:
# 0    724
# 1    724
# Name: count, dtype: int64

# %% [markdown]
# # **MODEL TESTING**

# %% [markdown]
# # SUPPORT VECTOR MACHINE

# %% [markdown]
# Testing in train set

# %%
odel = svm.SVC()
model.fit(X_resampled, y_resampled)
y_pred = model.predict(X_resampled)
print("Train Accuracy:", accuracy_score(y_resampled, y_pred))
# Out:
# Train Accuracy: 1.0

# %% [markdown]
# Testing in train set

# %%
model1 = svm.SVC()
model.fit(X_resampled, y_resampled)
y_pred = model.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix, classification_report

confusion_matrix = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(confusion_matrix)

classification_report = classification_report(y_test, y_pred)

print("Classification Report:")
print(classification_report)
# Out:
# Test Accuracy: 1.0
# Confusion Matrix:
# [[ 58   0]
#  [  0 189]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        58
#            1       1.00      1.00      1.00       189
#
#     accuracy                           1.00       247
#    macro avg       1.00      1.00      1.00       247
# weighted avg       1.00      1.00      1.00       247

# %% [markdown]
# WITH HYPERPARAMETERS

# %%
model = svm.SVC(C=0.1,kernel="rbf")
model.fit(X_resampled, y_resampled)
y_pred = model.predict(X_test)
print("Test Accuracy:", accuracy_score(y_test, y_pred))

from sklearn.metrics import confusion_matrix, classification_report

confusion_matrix = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(confusion_matrix)

classification_report = classification_report(y_test, y_pred)

print("Classification Report:")
print(classification_report)
# Out:
# Test Accuracy: 0.8947368421052632
# Confusion Matrix:
# [[ 55   3]
#  [ 23 166]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.71      0.95      0.81        58
#            1       0.98      0.88      0.93       189
#
#     accuracy                           0.89       247
#    macro avg       0.84      0.91      0.87       247
# weighted avg       0.92      0.89      0.90       247

# %% [markdown]
# # LOGISTIC REGRESSION

# %% [markdown]
# Testing in train set

# %%
model = LogisticRegression(max_iter=1000,penalty="l2",solver="lbfgs",C=0.001)
model.fit(X_resampled, y_resampled)


y_pred = model.predict(X_resampled)

print("Test Accuracy:", accuracy_score(y_resampled, y_pred))
# Out:
# Test Accuracy: 0.9558011049723757

# %% [markdown]
# Testing in test set

# %%
from sklearn.metrics import confusion_matrix, classification_report

model = LogisticRegression(max_iter=1000,penalty="l2",solver="lbfgs",C=0.001)
model.fit(X_resampled, y_resampled)


y_pred = model.predict(X_test)

print("Test Accuracy:", accuracy_score(y_test, y_pred))

confusion_matrix = confusion_matrix(y_test, y_pred)


print("Confusion Matrix:")
print(confusion_matrix)

classification_report = classification_report(y_test, y_pred)

print("Classification Report:")
print(classification_report)
# Out:
# Test Accuracy: 0.9473684210526315
# Confusion Matrix:
# [[ 56   2]
#  [ 11 178]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.97      0.90        58
#            1       0.99      0.94      0.96       189
#
#     accuracy                           0.95       247
#    macro avg       0.91      0.95      0.93       247
# weighted avg       0.95      0.95      0.95       247

# %% [markdown]
# WITH HYPERPARAMETERS

# %%
from sklearn.metrics import confusion_matrix, classification_report

model = LogisticRegression(penalty="l1",C=0.01,solver="liblinear")
model.fit(X_resampled, y_resampled)


y_pred = model.predict(X_test)

print("Test Accuracy:", accuracy_score(y_test, y_pred))

confusion_matrix = confusion_matrix(y_test, y_pred)


print("Confusion Matrix:")
print(confusion_matrix)

classification_report = classification_report(y_test, y_pred)

print("Classification Report:")
print(classification_report)
# Out:
# Test Accuracy: 0.9595141700404858
# Confusion Matrix:
# [[ 56   2]
#  [  8 181]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92        58
#            1       0.99      0.96      0.97       189
#
#     accuracy                           0.96       247
#    macro avg       0.93      0.96      0.95       247
# weighted avg       0.96      0.96      0.96       247

# %% [markdown]
# Testing with inputs

# %%
X.to_csv('new_data1.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 X.to_csv('new_data1.csv', index=False)
#
# NameError: name 'X' is not defined

# %%
import pickle

# %%
import pickle
filename = 'liver_cirosis.pkl'
pickle.dump(model1, open(filename, 'wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pickle
#       2 filename = 'liver_cirosis.pkl'
# ----> 3 pickle.dump(model1, open(filename, 'wb'))
#
# NameError: name 'model1' is not defined

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Duration of alcohol consumption(years)',
#        'Quantity of alcohol consumption (quarters/day)',
#        'Type of alcohol consumed', 'Hepatitis B infection',
#        'Hepatitis C infection', 'Diabetes Result', 'Blood pressure (mmhg)',
#        'Obesity', 'Family history of cirrhosis/ hereditary', 'TCH', 'TG',
#        'LDL', 'HDL', 'Hemoglobin  (g/dl)', 'PCV  (%)',
#        'RBC  (million cells/microliter)', 'MCV   (femtoliters/cell)',
#        'MCH  (picograms/cell)', 'MCHC  (grams/deciliter)', 'Total Count',
#        'Polymorphs  (%) ', 'Lymphocytes  (%)', 'Monocytes   (%)',
#        'Eosinophils   (%)', 'Basophils  (%)', 'Platelet Count  (lakhs/mm)',
#        'Total Bilirubin    (mg/dl)', 'Direct    (mg/dl)',
#        'Indirect     (mg/dl)', 'Total Protein     (g/dl)', 'Albumin   (g/dl)',
#        'Globulin  (g/dl)', 'A/G Ratio', 'AL.Phosphatase      (U/L)',
#        'SGOT/AST      (U/L)', 'SGPT/ALT (U/L)',
#        'USG Abdomen (diffuse liver or  not)', 'Outcome'],
#       dtype='object')

# %%
model1.save("liver.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 model1.save("liver.h5")
#
# NameError: name 'model1' is not defined

# %%
import joblib
joblib.dump(model1, 'svm_liver_cirosis_model.pkl')
